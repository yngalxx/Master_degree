# %%
import cv2
import matplotlib.pyplot as plt
import ast
from tqdm.notebook import tqdm
import csv
import random
import hashlib
import numpy as np
import os
from operator import itemgetter 
from os import listdir
from os.path import isfile, join
import pandas as pd
import json

DIR_PATH = '/Users/alexdrozdz/Desktop/Studia/00. Seminarium magisterskie/'

# %%
# get metadata 
file = open(DIR_PATH + "Master_degree/additional_data/bw_website_data.json", "r")

metadata = json.load(file)

# %%
metadata
# Out:
# {'data': [{'id': '6057f064021d110001000d63',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918101601/0168.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 125.38053097345133,
#     'y': 839.5013318834625,
#     'width': 1820.7433628318583,
#     'height': 2714.751060246522,
#     'label': 'Illustration/Photo'},
#    'width': 6776,
#    'height': 9336,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-10-16/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-10-16/ed-1/seq-3/',
#     'subject_description': 'The Ogden standard. October 16, 1918. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918101601/0168.xml'},
#    'data': {'caption': 'HERE\'S NEW GOWN THAT SAVES COAL\nTo save coal-put on more clothes, ladles!\nHere\'s the new fuel-saving dress-and worn by no less a social star than Mrs. Angier B. Duke of Philadelphia-she that was Miss Cordelia Biddle of New York, Newport and Palm Beach.\nWhen Mrs. Angier B. Duke strolled down Fifth-av, New York, one chill October afternoon her new gown was so warm that she dispensed with a coat altogether. Worn in a steam or furnace heated apartment this fuel-saving gown would keep its wearer comfortable at a temperature of 50 degrees!\nFrench and Russian women have long been accustomed to cold rooms and instead of demanding more heat and more use of precious coal, have learned to dress for warmth as well as beauty.\nNow, as the war requires more fuel for ships and munitions there is less for house-heating-and English and American women are substituting fur and wool for "more steam, please."\nThis particular fuel-saving gown is of French blue wool velour, marvelously soft and heavy, and is richly embroidered in navy blue chenille, with chenille balls dangling from a hundred places. The sleeves are long and bell-shaped over a close-fitting cuff of lace. It shows the-new high neck line and the long, long, tight skirt, descending quite to the ankle to meet the new short-topped boots.\nFurs and a big, untrimmed velvet hat complete a costume that will withstand any weather above zero-and delight the heart of Mr. Garfield, Fuel-saver to his Majesty, The War!\nMRS. ANGIER B. DUKE, NEW YORK SOCIAL LEADER, IN FUEL-SAVING GOWN.',
#     'category': 'Photograph'}},
#   {'id': '6056d0cc379fd1000100069c',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/dlc_self_ver01/data/sn83030214/0020653218A/1917090201/0062.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 107.12271977093266,
#     'y': 1168.3853856562923,
#     'width': 893.787925922743,
#     'height': 2072.9418132611636,
#     'label': 'Illustration/Photo'},
#    'width': 6348,
#    'height': 8415,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83030214/1917-09-02/ed-1/seq-42/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83030214/1917-09-02/ed-1/seq-42/',
#     'subject_description': 'New-York tribune. September 02, 1917. Page 42',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/dlc_self_ver01/data/sn83030214/0020653218A/1917090201/0062.xml'},
#    'data': {'caption': 'Major General Leonard Wood\n—Greeley Photo Service'}},
#   {'id': '6050edde4fcf3a0001000007',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/deu_descendo_ver01/data/sn84026820/00271765095/1917071401/0231.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 182.9847416016451,
#     'y': 333.2959147597742,
#     'width': 1620.7330374107964,
#     'height': 1241.6906628305312,
#     'label': 'Illustration/Photo'},
#    'width': 6032,
#    'height': 8376,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn84026820/1917-07-14/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn84026820/1917-07-14/ed-1/seq-3/',
#     'subject_description': 'Middletown transcript. July 14, 1917. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/deu_descendo_ver01/data/sn84026820/00271765095/1917071401/0231.xml'},
#    'data': {'caption': 'The Real Adventure',
#     'creator': 'Henry Kitchell Webster',
#     'category': 'Editorial Cartoon'}},
#   {'id': '60560a34379fd1000100068d',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/okhi_caddo_ver01/data/sn85042344/00200295031/1917052701/0216.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 139.30262122850382,
#     'y': 301.2075103998801,
#     'width': 1852.42629065379,
#     'height': 768.0791515196942,
#     'label': 'Illustration/Photo'},
#    'width': 4680,
#    'height': 6279,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85042344/1917-05-27/ed-1/seq-23/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85042344/1917-05-27/ed-1/seq-23/',
#     'subject_description': 'Tulsa daily world. May 27, 1917. Page 23',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/okhi_caddo_ver01/data/sn85042344/00200295031/1917052701/0216.xml'},
#    'data': {'caption': 'The Remodeled Gown\nBy Gertrude Beresford\nThe purpose of this department is to help you with your remodel problems. I will be glad to answer questions or to supply ideas for your individual requirements. A description of the color and style of your old gown, together with a description of your figure and coloring will enable me to reply to your questions more intelligently and in greater detail. Address Gertrude Beresford, c/o this paper, and enclose a stamped, addressed envelope for a direct and prompt reply.',
#     'category': 'Illustration'}},
#   {'id': '5ffe05928902e2000100093c',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918052501/0743.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 4863.808845645172,
#     'y': 690.0912516457075,
#     'width': 1758.405743647927,
#     'height': 1194.388704771417,
#     'label': 'Illustration/Photo'},
#    'width': 6808,
#    'height': 9135,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-25/ed-1/seq-26/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-25/ed-1/seq-26/',
#     'subject_description': 'The Ogden standard. May 25, 1918. Page 26',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918052501/0743.xml'},
#    'data': {'values': [{'caption': 'Deck View', 'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '6050f35c4fcf3a0001000013',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918051701/0625.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 214.40064360418341,
#     'y': 2170.1471887820494,
#     'width': 1757.039420756235,
#     'height': 2368.8594614898034,
#     'label': 'Illustration/Photo'},
#    'width': 6500,
#    'height': 9053,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-17/ed-1/seq-8/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-17/ed-1/seq-8/',
#     'subject_description': 'The Ogden standard. May 17, 1918. Page 8',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918051701/0625.xml'},
#    'data': {'values': [{'caption': 'LEE MORRISSEY', 'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '60020ae68902e2000100097d',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918050201/0430.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 161.8111693433649,
#     'y': 377.62866880193315,
#     'width': 6264.5897521019515,
#     'height': 775.4874448611132,
#     'label': 'Illustration/Photo'},
#    'width': 6804,
#    'height': 9244,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-02/ed-1/seq-7/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-02/ed-1/seq-7/',
#     'subject_description': 'The Ogden standard. May 02, 1918. Page 7',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918050201/0430.xml'},
#    'data': {'caption': 'IN MERRY MOOD'}},
#   {'id': '5fb55a6e021d110001000a00',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918032201/0472.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 378.1192107070664,
#     'y': 4041.217298211016,
#     'width': 945.3139536499467,
#     'height': 1953.6489082969429,
#     'label': 'Illustration/Photo'},
#    'width': 6436,
#    'height': 8738,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-03-22/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-03-22/ed-1/seq-3/',
#     'subject_description': 'The Owosso times. March 22, 1918. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918032201/0472.xml'},
#    'data': {'caption': 'Scarcely Felt the Blow.',
#     'creator': 'Walters',
#     'category': 'Illustration'}},
#   {'id': '5f62c2b78902e20001000436',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_indurain_ver01/data/sn85058396/print/1917112401/0683.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 4878.79104477612,
#     'y': 1505.1041108690192,
#     'width': 1617.7313432835826,
#     'height': 870.2982954004533,
#     'label': 'Illustration/Photo'},
#    'width': 6860,
#    'height': 9354,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1917-11-24/ed-1/seq-10/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1917-11-24/ed-1/seq-10/',
#     'subject_description': 'The Ogden standard. November 24, 1917. Page 10',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_indurain_ver01/data/sn85058396/print/1917112401/0683.xml'},
#    'data': {'category': 'Illustration'}},
#   {'id': '5ffec93a52d5b10001000ccb',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_indurain_ver01/data/sn85058396/print/1917070601/0042.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 3104.5732565579015,
#     'y': 563.652838417365,
#     'width': 1825.1669865642993,
#     'height': 2106.987991226817,
#     'label': 'Illustration/Photo'},
#    'width': 6992,
#    'height': 9464,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1917-07-06/ed-1/seq-5/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1917-07-06/ed-1/seq-5/',
#     'subject_description': 'The Ogden standard. July 06, 1917. Page 5',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_indurain_ver01/data/sn85058396/print/1917070601/0042.xml'},
#    'data': {'caption': "LLOYD-GEORGE'S DAUGHTER NOW A BRIDE\nCapt. and Mrs. T. J. Carey Evans.\nCapt T. J. Carey Evans, a British fighting man on the French front, recently secured a leave of absence of sufficient length to permit him to return to London and marry Miss Alwyn Lloyd-George, a daughter of the British premier. The wedding took place the middle of June at the Welsh Baptist church in London."}},
#   {'id': '5ffec8f252d5b10001000cc9',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/iune_india_ver01/data/sn83045487/00280761333/1917041701/0829.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 95.76284965192532,
#     'y': 768.3013395195876,
#     'width': 1500.6128226446344,
#     'height': 1799.4837890988324,
#     'label': 'Illustration/Photo'},
#    'width': 1812,
#    'height': 2751,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045487/1917-04-17/ed-1/seq-23/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045487/1917-04-17/ed-1/seq-23/',
#     'subject_description': 'The day book. April 17, 1917. Page 23',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/iune_india_ver01/data/sn83045487/00280761333/1917041701/0829.xml'},
#    'data': {'caption': 'HOLDS SCHOOL ON BATHING BEACH\nHere is the most modern school of all - on the beach at Venice, Cal. Miss Lillian Bishop, teacher, is shown with two pupils in bathing costume. After lessons teacher and class go in for a dip.',
#     'creator': 'Underwood-Underwood',
#     'category': 'Photograph'}},
#   {'id': '5fd2c9088902e200010007d7',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/lu_roulette_ver01/data/sn87090131/0020029970A/1918051001/0169.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2584.2901960784316,
#     'y': 309.1346684188918,
#     'width': 761.5267973856207,
#     'height': 2435.377997543953,
#     'label': 'Illustration/Photo'},
#    'width': 5768,
#    'height': 8120,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn87090131/1918-05-10/ed-1/seq-6/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn87090131/1918-05-10/ed-1/seq-6/',
#     'subject_description': 'Tensas gazette. May 10, 1918. Page 6',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/lu_roulette_ver01/data/sn87090131/0020029970A/1918051001/0169.xml'},
#    'data': {'caption': 'DOES STARTING STUNTS\n"Hair-raising stunts" by student aviators may seem foolhardy to the average civilian, but the knowledge of them will save many lives in aerial battle, according to Lieut. Col. Charles R. Lee of the British Royal Flying corps, who has been startling Washington for several days with seemingly impossible feats in the air. Colonel Lee\'s demonstrations have done much to lessen the criticism in official Washington that student flyers have been killed because of foolhardy tricks rather than in straight straight flying at American training fields. "The so called danger of flying lies not with those who do stunts in the air." says Colonel Lee, but with those who cannot do them. Unless a pilot can turn his machine any way and every way at any time In order to maneuver for position, all the straight flying the world will not help him when he has a fight."',
#     'category': 'Photograph'}},
#   {'id': '5fc2b565021d110001000a6f',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/ct_berlin_ver01/data/sn82014086/0029586610A/1917041601/0453.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 189.56169463810298,
#     'y': 309.63852058618284,
#     'width': 745.6601534003073,
#     'height': 366.51090191833885,
#     'label': 'Illustration/Photo'},
#    'width': 6376,
#    'height': 6933,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn82014086/1917-04-16/ed-1/seq-4/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn82014086/1917-04-16/ed-1/seq-4/',
#     'subject_description': 'Norwich bulletin. April 16, 1917. Page 4',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/ct_berlin_ver01/data/sn82014086/0029586610A/1917041601/0453.xml'},
#    'data': {'caption': 'Norwich Bulletin\nand Courier',
#     'category': 'Illustration'}},
#   {'id': '5eb58105e994040001000386',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_indurain_ver01/data/sn85058396/print/1918082001/0553.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 4732.438805970149,
#     'y': 3708.4055555809905,
#     'width': 1669.9910447761195,
#     'height': 1095.774028681351,
#     'label': 'Illustration/Photo'},
#    'width': 6412,
#    'height': 9186,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-08-20/ed-1/seq-8/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-08-20/ed-1/seq-8/',
#     'subject_description': 'The Ogden standard. August 20, 1918. Page 8',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_indurain_ver01/data/sn85058396/print/1918082001/0553.xml'},
#    'data': {'values': [{'caption': 'Our Immense Barley Crop\nBarley at $1.20\nAs profitable as\nWheat at $2.00',
#       'category': 'Illustration'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5fb564c18902e20001000731',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237282449/1918042201/0392.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1214.5045161891628,
#     'y': 466.3508687038859,
#     'width': 2499.459459459459,
#     'height': 1580.5389047698202,
#     'label': 'Illustration/Photo'},
#    'width': 5100,
#    'height': 6637,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-04-22/ed-1/seq-15/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-04-22/ed-1/seq-15/',
#     'subject_description': 'Evening public ledger. April 22, 1918. Page 15',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237282449/1918042201/0392.xml'},
#    'data': {'caption': "Brooklyn Pins Faith on New Players This Year\nMitchell and O'Mara\nTillman and Ted Lewis to Meet in Denver"}},
#   {'id': '5ec2cd6d52d5b10001000429',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/lu_roulette_ver01/data/sn87090131/0020029970A/1918051001/0165.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2551.9288436903566,
#     'y': 2615.48521584037,
#     'width': 786.1888796181538,
#     'height': 895.1296156954545,
#     'label': 'Illustration/Photo'},
#    'width': 5792,
#    'height': 8144,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn87090131/1918-05-10/ed-1/seq-2/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn87090131/1918-05-10/ed-1/seq-2/',
#     'subject_description': 'Tensas gazette. May 10, 1918. Page 2',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/lu_roulette_ver01/data/sn87090131/0020029970A/1918051001/0165.xml'},
#    'data': {'values': [{'caption': 'First Prize Shropshire.',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5fb55a6052d5b10001000a87',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918020101/0416.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 4292.645474138268,
#     'y': 2938.1504240632576,
#     'width': 1767.8009361382283,
#     'height': 1931.4860726432562,
#     'label': 'Illustration/Photo'},
#    'width': 6396,
#    'height': 8911,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-02-01/ed-1/seq-4/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-02-01/ed-1/seq-4/',
#     'subject_description': 'The Owosso times. February 01, 1918. Page 4',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918020101/0416.xml'},
#    'data': {'caption': 'How Does a Soldier Feel in a Life-and-Death Crisis?\nHe was caught- like a rat in a trap- with only one chance in a million of coming out alive. He thought of-\nWhat does a soldier think of in a life-and-death crisis? How does he feel? What does he do? What is the millionth chance that he takes to escape?\nWhile trembling and hot from the experiences they have gone through, over two hundred men- airmen, trench raiders, submarine commanders, grenade throwers- have told what they saw, heard and felt. To read these stories of personal adventure is to get an entirely new viewpoint of the war.',
#     'category': 'Editorial Cartoon'}},
#   {'id': '5f6165508902e200010003f6',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_basso_ver01/data/sn85058246/00206536263/1917041701/0408.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1485.2328232174345,
#     'y': 3040.0532077250564,
#     'width': 623.2290441989544,
#     'height': 2054.4817267939297,
#     'label': 'Illustration/Photo'},
#    'width': 4272,
#    'height': 6250,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058246/1917-04-17/ed-1/seq-6/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058246/1917-04-17/ed-1/seq-6/',
#     'subject_description': 'The Logan Republican. April 17, 1917. Page 6',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_basso_ver01/data/sn85058246/00206536263/1917041701/0408.xml'},
#    'data': {'caption': 'See the blandishments of the fashionable Mrs. Taine in her efforts to ensnare the young Aaron King and drag him down to her level of deals. LYRIC THEATRE, WEDNESDAY AND THURSDAY.',
#     'category': 'Photograph'}},
#   {'id': '5fb55a36021d1100010009fe',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918041901/0504.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 348.921445889537,
#     'y': 2477.5162731825176,
#     'width': 1037.0253881826425,
#     'height': 1659.3089075918497,
#     'label': 'Illustration/Photo'},
#    'width': 6472,
#    'height': 8834,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-04-19/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-04-19/ed-1/seq-3/',
#     'subject_description': 'The Owosso times. April 19, 1918. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918041901/0504.xml'},
#    'data': {'caption': 'DELIGHTED.\nWifey-The magazine is fine this month.\nHubby-Is it?\nWifey-Yes, dear; seven pages of reading matter and only 270 of incubator and flower seed ads.',
#     'category': 'Comics/Cartoon'}},
#   {'id': '5fb55a0752d5b10001000a85',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917101201/0286.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 216.66693892573628,
#     'y': 3260.188366415638,
#     'width': 922.1242862652862,
#     'height': 1970.2220266901309,
#     'label': 'Illustration/Photo'},
#    'width': 6344,
#    'height': 9127,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-10-12/ed-1/seq-7/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-10-12/ed-1/seq-7/',
#     'subject_description': 'The Owosso times. October 12, 1917. Page 7',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917101201/0286.xml'},
#    'data': {'caption': '"Step Outl" Ordered the Farmer.',
#     'category': 'Illustration'}},
#   {'id': '5fb559768902e20001000721',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/whi_elizabeth_ver01/data/sn85040720/00271769581/1917072701/0124.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 3380.7598450082146,
#     'y': 408.02361382316883,
#     'width': 1008.4012989421731,
#     'height': 1457.2271922256027,
#     'label': 'Illustration/Photo'},
#    'width': 7665,
#    'height': 10028,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85040720/1917-07-27/ed-1/seq-4/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85040720/1917-07-27/ed-1/seq-4/',
#     'subject_description': 'The Watertown news. July 27, 1917. Page 4',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/whi_elizabeth_ver01/data/sn85040720/00271769581/1917072701/0124.xml'},
#    'data': {'caption': 'GAME\nFISHING\nby\nDIXIE\nCARROLL\nAuthor of LAKE and\nSTREAM GAME FISHING',
#     'creator': 'Stewart N Kidd Co',
#     'category': 'Illustration'}},
#   {'id': '5fb55997021d1100010009fb',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917101901/0295.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2949.4757361181873,
#     'y': 687.3599324169733,
#     'width': 2713.5327631321024,
#     'height': 3267.5244548478504,
#     'label': 'Illustration/Photo'},
#    'width': 6376,
#    'height': 9108,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-10-19/ed-1/seq-7/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-10-19/ed-1/seq-7/',
#     'subject_description': 'The Owosso times. October 19, 1917. Page 7',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917101901/0295.xml'},
#    'data': {'caption': 'FOR LIBERTY AND DEMOCRACY--BUY A BOND',
#     'category': 'Illustration'}},
#   {'id': '5fba82d652d5b10001000acf',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237282437/1918051401/0848.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2521.2733219607458,
#     'y': 245.00156501779483,
#     'width': 610.2766552785429,
#     'height': 953.2788166146926,
#     'label': 'Illustration/Photo'},
#    'width': 4900,
#    'height': 6004,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-05-14/ed-1/seq-19/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-05-14/ed-1/seq-19/',
#     'subject_description': 'Evening public ledger. May 14, 1918. Page 19',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237282437/1918051401/0848.xml'},
#    'data': {'caption': '"Alast Unconscious of Their Doom!"\n-London Bystander\nPets In the park--edible and otherwise.'}},
#   {'id': '5fba81c3021d110001000a50',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918052501/0743.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2183.069523253617,
#     'y': 610.4653379942797,
#     'width': 2667.4683356470437,
#     'height': 2116.7222045671224,
#     'label': 'Illustration/Photo'},
#    'width': 6808,
#    'height': 9135,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-25/ed-1/seq-26/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-25/ed-1/seq-26/',
#     'subject_description': 'The Ogden standard. May 25, 1918. Page 26',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918052501/0743.xml'},
#    'data': {'caption': 'Three Chasers in Speed Trial',
#     'category': 'Photograph'}},
#   {'id': '5fb56db0379fd100010003a5',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237282449/1918041101/0194.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1417.621160038541,
#     'y': 452.6563923274088,
#     'width': 631.6135551251069,
#     'height': 1442.1843197408145,
#     'label': 'Illustration/Photo'},
#    'width': 5148,
#    'height': 6564,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-04-11/ed-1/seq-10/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-04-11/ed-1/seq-10/',
#     'subject_description': 'Evening public ledger. April 11, 1918. Page 10',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237282449/1918041101/0194.xml'},
#    'data': {'caption': '"HOME FIRES" IN CITY SCHOOLS EDITORIAL FOR WOMEN, BY A WOMAN\nBy MARY V. GRICE'}},
#   {'id': '5fb559fa8902e20001000725',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917070601/0167.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2339.183847917949,
#     'y': 1641.3145204500802,
#     'width': 891.7378427660537,
#     'height': 2067.7978210394713,
#     'label': 'Illustration/Photo'},
#    'width': 6520,
#    'height': 9045,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-07-06/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-07-06/ed-1/seq-3/',
#     'subject_description': 'The Owosso times. July 06, 1917. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917070601/0167.xml'},
#    'data': {'caption': 'WITH AMY AND ME THE MYSTERY WAS\nALREADY CLEAR.',
#     'category': 'Illustration'}},
#   {'id': '5fb559aa8902e20001000723',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918061501/0993.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 3915.6448266519387,
#     'y': 301.20458789010405,
#     'width': 2827.2158783419995,
#     'height': 2149.5054681248334,
#     'label': 'Illustration/Photo'},
#    'width': 6736,
#    'height': 9223,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-06-15/ed-1/seq-16/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-06-15/ed-1/seq-16/',
#     'subject_description': 'The Ogden standard. June 15, 1918. Page 16',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918061501/0993.xml'},
#    'data': {'caption': 'MOVING WOUNDED AMERICAN SOLDIERS IN FBANCE; THESE LADS WERE IN THE THICK OF GREAT BATTLE\nThe bravery, dashing spirit, endurance and cheerful spirit of the American soldiers now showing their metal in the battle on the western front, are winning the praise and gratitude of the troops of the other allies. The American lads are given the glad hand wherever they go. The wounded fellows are given the best of care at hand until they can be taken back to the hospitals. The picture shows some of the U.S. lads, hit in battling the Hun, being placed on a hospital train to be taken to a base hospital.',
#     'creator': '',
#     'category': 'Photograph'}},
#   {'id': '5fb5598c52d5b10001000a80',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917060801/0133.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2322.518740629685,
#     'y': 1462.685819421215,
#     'width': 1719.6521739130435,
#     'height': 2618.9982577474457,
#     'label': 'Illustration/Photo'},
#    'width': 6592,
#    'height': 8997,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-06-08/ed-1/seq-1/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-06-08/ed-1/seq-1/',
#     'subject_description': 'The Owosso times. June 08, 1917. Page 1',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917060801/0133.xml'},
#    'data': {'caption': "The FLAG GOES\nBY BY H.H.BENNETT\nHats off!\nAlong the street there comes\nA blare of bugles, a ruffle of drums,\nA flash of color beneath the sky;\nHats off! The flag Is passing by!\nBlue and crimson and white it shines,\nOver the steel-tipped, ordered lines.\nHats off!\nThe colors before us fly;\nBut more than the flag is passing by.\nSea-fights and land-fights, grim and great.\nFought to make and to save the State;\nWeary marches and sinking ships;\nCheers of victory on dying lips;\nDays of plenty and years of peace;\nMarch of a strong land's swift increase;\nEqual-Justice, right and law.\nStately honor and reverend awe;\nSign of a nation, great and strong\nTo ward her people from foreign wrongs\nPride and glory and honor, all\nLive in the colors to stand or fall.\nHats off!\nAlong the street there comes\nA blare of bugles, a ruffle of drums;\nAnd loyal hearts are beating high:\nHats off The flag is passing by!\n-Youth's Companion.\nVJ I\nI Wc W En I JI\nl",
#     'category': 'Illustration'}},
#   {'id': '5fb565ef8902e20001000737',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237282449/1918041101/0194.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2053.1993799548695,
#     'y': 456.1653566090165,
#     'width': 1877.2958443996247,
#     'height': 1943.966212010732,
#     'label': 'Illustration/Photo'},
#    'width': 5148,
#    'height': 6564,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-04-11/ed-1/seq-10/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-04-11/ed-1/seq-10/',
#     'subject_description': 'Evening public ledger. April 11, 1918. Page 10',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237282449/1918041101/0194.xml'},
#    'data': {'caption': 'GIRL NAMED HEAD OF PENN LAW FRESHMEN DOESNT CALL IT "JUST SIMPLY WONDERFUL"',
#     'category': 'Photograph'}},
#   {'id': '5fb563e4021d110001000a13',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918052501/0743.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 384.85081937215256,
#     'y': 690.0912516457075,
#     'width': 1784.947717136952,
#     'height': 1240.8371544014167,
#     'label': 'Illustration/Photo'},
#    'width': 6808,
#    'height': 9135,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-25/ed-1/seq-26/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-25/ed-1/seq-26/',
#     'subject_description': 'The Ogden standard. May 25, 1918. Page 26',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918052501/0743.xml'},
#    'data': {'caption': 'Broadside View Latest Type High Powered Chaser',
#     'category': 'Photograph'}},
#   {'id': '5fb563d952d5b10001000a98',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237282437/1918051401/0848.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1919.9058149344444,
#     'y': 227.18326938013703,
#     'width': 596.9129329001805,
#     'height': 801.8233036946012,
#     'label': 'Illustration/Photo'},
#    'width': 4900,
#    'height': 6004,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-05-14/ed-1/seq-19/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-05-14/ed-1/seq-19/',
#     'subject_description': 'Evening public ledger. May 14, 1918. Page 19',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237282437/1918051401/0848.xml'},
#    'data': {'caption': 'THE CHEERFUL CHERUB'}},
#   {'id': '5f8bc335021d1100010008f3',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_indurain_ver01/data/sn85058396/print/1917112201/0655.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1147.8554957724828,
#     'y': 819.153436933491,
#     'width': 1826.1337432744044,
#     'height': 3088.7823863988965,
#     'label': 'Illustration/Photo'},
#    'width': 6788,
#    'height': 9278,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1917-11-22/ed-1/seq-2/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1917-11-22/ed-1/seq-2/',
#     'subject_description': 'The Ogden standard. November 22, 1917. Page 2',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_indurain_ver01/data/sn85058396/print/1917112201/0655.xml'},
#    'data': {'caption': 'BACKFIELD MEN MAKE TECH "WONDER TEAM"\nEVERETT STRUPPER\nThis year Georgia Tech has produced one of the really great backflelds of the country led by Everett Strupper, one of the superbacks of 1916 and Joe Guyon, the former Carlisle star.\nThe rest of the team is not much inferior to these stars and working under the leadership of J. W. Heisman has developed into one of tho most feared scoring machines of the decade.',
#     'category': 'Photograph'}},
#   {'id': '5fb558fd379fd10001000387',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918051701/0537.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2324.326974121094,
#     'y': 355.1360445734273,
#     'width': 910.752,
#     'height': 853.4721071200107,
#     'label': 'Illustration/Photo'},
#    'width': 6444,
#    'height': 8870,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-05-17/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-05-17/ed-1/seq-3/',
#     'subject_description': 'The Owosso times. May 17, 1918. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918051701/0537.xml'},
#    'data': {'caption': 'FARM\nPOULTRY', 'category': 'Illustration'}},
#   {'id': '5f8bca688902e2000100060e',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_indurain_ver01/data/sn85058396/print/1918071701/0187.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2041.9295030240783,
#     'y': 596.8683933973208,
#     'width': 881.6129803179952,
#     'height': 1922.0257438757762,
#     'label': 'Illustration/Photo'},
#    'width': 6456,
#    'height': 9034,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-07-17/ed-1/seq-10/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-07-17/ed-1/seq-10/',
#     'subject_description': 'The Ogden standard. July 17, 1918. Page 10',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_indurain_ver01/data/sn85058396/print/1918071701/0187.xml'},
#    'data': {'caption': 'WILLIAM VAN ALEN DIES AT SUMMER HOME IN CANYON',
#     'category': 'Photograph'}},
#   {'id': '5f8bc475379fd1000100026d',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237287654/1918032201/0914.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1881.137338136589,
#     'y': 435.079573945004,
#     'width': 1199.1217511007465,
#     'height': 1846.4351791374406,
#     'label': 'Illustration/Photo'},
#    'width': 5144,
#    'height': 6631,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-03-22/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-03-22/ed-1/seq-3/',
#     'subject_description': 'Evening public ledger. March 22, 1918. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237287654/1918032201/0914.xml'},
#    'data': {'caption': '"ALICE" WINS JUVENILE HEARTS\nWee, winsome "Alice," Jessie Willcox Smith\'s charming contribution to the 113th annual exhibit of the Academy of the Fine Arts, was crowned queen in a popularity contest held among 500 school childrnen, who viewed the exhibit as guests of the Civic Club. The portrait is one of the most winning of all Miss Smith\'s felicitous studies of childhood.',
#     'category': 'Photograph'}},
#   {'id': '5f8bc04252d5b10001000957',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_fignon_ver01/data/sn86091025/00280765661/1918080901/1022.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1729.008497709373,
#     'y': 220.84233544719004,
#     'width': 1901.3985987984197,
#     'height': 2370.0153072381368,
#     'label': 'Illustration/Photo'},
#    'width': 4336,
#    'height': 6158,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn86091025/1918-08-09/ed-1/seq-4/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn86091025/1918-08-09/ed-1/seq-4/',
#     'subject_description': 'The Sun. August 09, 1918. Page 4',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_fignon_ver01/data/sn86091025/00280765661/1918080901/1022.xml'},
#    'data': {'caption': 'THE HOPE OF NATIONS',
#     'creator': 'H. Devitt Welsh',
#     'category': 'Editorial Cartoon'}},
#   {'id': '5fb556d6379fd1000100037e',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237287691/1917071601/1021.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1320.3593631039164,
#     'y': 273.15144070241973,
#     'width': 2066.145361020188,
#     'height': 2041.6319221732142,
#     'label': 'Illustration/Photo'},
#    'width': 5096,
#    'height': 6637,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-07-16/ed-1/seq-15/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-07-16/ed-1/seq-15/',
#     'subject_description': 'Evening public ledger. July 16, 1917. Page 15',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237287691/1917071601/1021.xml'},
#    'data': {'caption': 'PETEY - It Must Be There Are Two of Them',
#     'creator': 'C.A. Voigka',
#     'category': 'Comics/Cartoon'}},
#   {'id': '5fb5588452d5b10001000a79',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237282437/1918051401/0848.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 62.34840434209116,
#     'y': 227.18326938013703,
#     'width': 1862.0119847184742,
#     'height': 2013.467407055332,
#     'label': 'Illustration/Photo'},
#    'width': 4900,
#    'height': 6004,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-05-14/ed-1/seq-19/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1918-05-14/ed-1/seq-19/',
#     'subject_description': 'Evening public ledger. May 14, 1918. Page 19',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237282437/1918051401/0848.xml'},
#    'data': {'caption': 'SCHOOL DAYS\nDown cellar after apples',
#     'creator': 'DWIG',
#     'category': 'Comics/Cartoon'}},
#   {'id': '5f8bb44f379fd1000100026b',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918053001/0784.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 996.4644174034426,
#     'y': 425.7062849920658,
#     'width': 896.2238142214734,
#     'height': 2016.5034552255747,
#     'label': 'Illustration/Photo'},
#    'width': 6604,
#    'height': 9091,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-30/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-05-30/ed-1/seq-3/',
#     'subject_description': 'The Ogden standard. May 30, 1918. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918053001/0784.xml'},
#    'data': {'caption': 'Corporal Wadsworth\nCorporal Williams Dale Wadsworth son of Mr. and Mrs. Frank Wadsworth of Riverdale, who returned to Camp Lewis, American Lake Wash., last Saturday after spending a fifteen-day furlough with his friends and relatives.',
#     'category': 'Photograph'}},
#   {'id': '5f90aed28902e20001000631',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237287678/1917100601/0345.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 96.55534229046705,
#     'y': 439.4902176319693,
#     'width': 1335.1273192578383,
#     'height': 426.17233224918243,
#     'label': 'Illustration/Photo'},
#    'width': 5204,
#    'height': 6801,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-10-06/ed-1/seq-13/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-10-06/ed-1/seq-13/',
#     'subject_description': 'Evening public ledger. October 06, 1917. Page 13',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237287678/1917100601/0345.xml'},
#    'data': {'caption': 'BOTH SIDES\nof the\nCURTAIN',
#     'category': 'Illustration'}},
#   {'id': '5b75a607d6342b0001002a17',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918011801/0403.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 745.086989437553,
#     'y': 3898.14088682658,
#     'width': 893.665818490246,
#     'height': 849.8056785627567,
#     'label': 'Illustration/Photo'},
#    'width': 6464,
#    'height': 8842,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-01-18/ed-1/seq-8/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1918-01-18/ed-1/seq-8/',
#     'subject_description': 'The Owosso times. January 18, 1918. Page 8',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1918011801/0403.xml'},
#    'data': {'values': [{'caption': 'Prevents Tangle in Rope.',
#       'category': 'Illustration'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5a8f3332639da000010010cc',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917070601/0169.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 341.24499211091285,
#     'y': 3477.2362031790603,
#     'width': 1806.2799717062644,
#     'height': 1770.978167778168,
#     'label': 'Illustration/Photo'},
#    'width': 6472,
#    'height': 9167,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-07-06/ed-1/seq-5/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-07-06/ed-1/seq-5/',
#     'subject_description': 'The Owosso times. July 06, 1917. Page 5',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917070601/0169.xml'},
#    'data': {'values': [{'caption': "COLONEL PATTEE'S OLD SOLDIER FIDDLERS.\nOwosso Chautauqua, July 21th to 27th",
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5c4f27b16dc3580001002e09',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/mimtptc_evart_ver01/data/sn97070614/0029602370A/1917101901/0290.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 3117.6784995659723,
#     'y': 1766.0632971151947,
#     'width': 888.6897777777776,
#     'height': 1386.8125588902656,
#     'label': 'Illustration/Photo'},
#    'width': 6368,
#    'height': 9094,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn97070614/1917-10-19/ed-1/seq-3/',
# ...
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e0b9c10e8c9c80001004ca9',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/kyu_dubnium_ver01/data/sn86069496/0028076324A/1917121201/0627.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2813.96621078037,
#     'y': 4488.940735610652,
#     'width': 795.0571198712792,
#     'height': 1527.579832416759,
#     'label': 'Illustration/Photo'},
#    'width': 5552,
#    'height': 8009,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn86069496/1917-12-12/ed-1/seq-4/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn86069496/1917-12-12/ed-1/seq-4/',
#     'subject_description': 'The Adair County news. December 12, 1917. Page 4',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/kyu_dubnium_ver01/data/sn86069496/0028076324A/1917121201/0627.xml'},
#    'data': {'values': [{'caption': 'The Rail Gave Way.',
#       'creator': 'Parker',
#       'category': 'Illustration'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e0b9929e8c9c80001004ca3',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/kyu_europium_ver01/data/sn87060032/00280763159/1917072701/0167.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1691.8779278640404,
#     'y': 2558.597570134747,
#     'width': 1234.9941390391973,
#     'height': 1722.3459833591041,
#     'label': 'Illustration/Photo'},
#    'width': 4328,
#    'height': 5876,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn87060032/1917-07-27/ed-1/seq-6/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn87060032/1917-07-27/ed-1/seq-6/',
#     'subject_description': 'Mountain advocate. July 27, 1917. Page 6',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/kyu_europium_ver01/data/sn87060032/00280763159/1917072701/0167.xml'},
#    'data': {'values': [{'caption': 'J. W. MESSAMORE',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e0f8020ebaf1800010074b4',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/kyu_aluminum_ver01/data/sn86069180/00211104089/1917102701/0588.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 385.4713689551322,
#     'y': 1486.9977799759558,
#     'width': 702.2228078057094,
#     'height': 1318.9549731775764,
#     'label': 'Illustration/Photo'},
#    'width': 5576,
#    'height': 7447,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn86069180/1917-10-27/ed-1/seq-4/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn86069180/1917-10-27/ed-1/seq-4/',
#     'subject_description': 'Kentucky Irish American. October 27, 1917. Page 4',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/kyu_aluminum_ver01/data/sn86069180/00211104089/1917102701/0588.xml'},
#    'data': {'values': [{'caption': 'VOTE THE STRAIGHT Democratic Ticket',
#       'category': 'Illustration'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e0b97c1ebaf18000100733a',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/kyu_europium_ver01/data/sn87060032/00280763159/1917072701/0167.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 440.26951789606466,
#     'y': 323.9782637508284,
#     'width': 1229.4560487296044,
#     'height': 1556.2032839997055,
#     'label': 'Illustration/Photo'},
#    'width': 4328,
#    'height': 5876,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn87060032/1917-07-27/ed-1/seq-6/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn87060032/1917-07-27/ed-1/seq-6/',
#     'subject_description': 'Mountain advocate. July 27, 1917. Page 6',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/kyu_europium_ver01/data/sn87060032/00280763159/1917072701/0167.xml'},
#    'data': {'values': [{'caption': 'W. C. ELLIOTT', 'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e1be902f35043000100505b',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237287678/1917102001/0606.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 3842.053173764241,
#     'y': 2142.2698392994375,
#     'width': 658.1474391655279,
#     'height': 608.7863598623594,
#     'label': 'Illustration/Photo'},
#    'width': 5272,
#    'height': 6815,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-10-20/ed-1/seq-14/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-10-20/ed-1/seq-14/',
#     'subject_description': 'Evening public ledger. October 20, 1917. Page 14',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237287678/1917102001/0606.xml'},
#    'data': {'caption': 'Frank Mackey, Gertrude Hayes, Chester Nelson\nEverything New—Three Burlesques ENTITLED "Oh You Shakespeare"',
#     'category': 'Photograph'}},
#   {'id': '5e1be8f0ca9e6f0001007517',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/wa_klickitat_ver01/data/sn87093407/00200290720/1917070401/0618.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1462.2687993900404,
#     'y': 262.58223987606016,
#     'width': 679.288828620009,
#     'height': 5793.934205960892,
#     'label': 'Illustration/Photo'},
#    'width': 5303,
#    'height': 7039,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn87093407/1917-07-04/ed-1/seq-10/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn87093407/1917-07-04/ed-1/seq-10/',
#     'subject_description': 'The Seattle star. July 04, 1917. Page 10',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/wa_klickitat_ver01/data/sn87093407/00200290720/1917070401/0618.xml'},
#    'data': {'caption': 'Independence Days of Allies\nJUNE 15 GREAT BRITAIN\nJULY 14 FRANCE\nMARCH 16 RUSSIA\nOCTOBER 4 BELGIUM\nJULY 2 ITALY',
#     'category': 'Illustration'}},
#   {'id': '5e1be8e6e8c9c80001005012',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_davey_ver01/data/sn83045211/00237287691/1917060101/0253.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 904.3970856923021,
#     'y': 240.97636859856692,
#     'width': 1355.4920092382272,
#     'height': 1212.41235451154,
#     'label': 'Illustration/Photo'},
#    'width': 5068,
#    'height': 6602,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-06-01/ed-1/seq-4/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn83045211/1917-06-01/ed-1/seq-4/',
#     'subject_description': 'Evening public ledger. June 01, 1917. Page 4',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_davey_ver01/data/sn83045211/00237287691/1917060101/0253.xml'},
#    'data': {'caption': 'A BIT OF FUN "ON THE FRONT"\nHerbert W. Crowhurst, of Philadelphia, master mechanician of the American Red Cross in France, sparring with a French poilu who knows no English except "cuss words."',
#     'category': 'Photograph'}},
#   {'id': '5e14fa4ce8c9c80001004f5d',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918110201/0379.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 5642.75966507587,
#     'y': 3481.528742476308,
#     'width': 420.4744993464574,
#     'height': 651.7354529997924,
#     'label': 'Illustration/Photo'},
#    'width': 6572,
#    'height': 9158,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-11-02/ed-1/seq-14/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-11-02/ed-1/seq-14/',
#     'subject_description': 'The Ogden standard. November 02, 1918. Page 14',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918110201/0379.xml'},
#    'data': {'values': [{'caption': 'Capable Women\nJottings About the Doings of the Fair Sex\nDR. MARY WALKER',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e14fa0aebaf1800010075e9',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918110201/0379.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 5184.442460788231,
#     'y': 2489.208955973399,
#     'width': 420.47449934645715,
#     'height': 660.1449427159184,
#     'label': 'Illustration/Photo'},
#    'width': 6572,
#    'height': 9158,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-11-02/ed-1/seq-14/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-11-02/ed-1/seq-14/',
#     'subject_description': 'The Ogden standard. November 02, 1918. Page 14',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918110201/0379.xml'},
#    'data': {'values': [{'caption': 'Capable Women\nJottings About the Doings of the Fair Sex\nMRS. WINSTON CHURCHILL',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e14f999f350430001004fb2',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/uuml_julich_ver01/data/sn85058396/print/1918110401/0398.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 309.54265336772875,
#     'y': 3039.708709583455,
#     'width': 1332.828367318727,
#     'height': 1702.580833090591,
#     'label': 'Illustration/Photo'},
#    'width': 6720,
#    'height': 9225,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-11-04/ed-1/seq-13/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85058396/1918-11-04/ed-1/seq-13/',
#     'subject_description': 'The Ogden standard. November 04, 1918. Page 13',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/uuml_julich_ver01/data/sn85058396/print/1918110401/0398.xml'},
#    'data': {'values': [{'caption': 'J. M. CHILD\nNominee of the Democratic Party for Election for Four-Year Commissioner.',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e176517ca9e6f00010074d1',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_greenberg_ver01/data/sn85038411/00296028307/1918080201/0861.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2221.2248800514694,
#     'y': 296.04852587991326,
#     'width': 2768.9243448176544,
#     'height': 2263.9004920228663,
#     'label': 'Illustration/Photo'},
#    'width': 5860,
#    'height': 7296,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85038411/1918-08-02/ed-1/seq-12/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85038411/1918-08-02/ed-1/seq-12/',
#     'subject_description': 'Harrisburg telegraph. August 02, 1918. Page 12',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_greenberg_ver01/data/sn85038411/00296028307/1918080201/0861.xml'},
#    'data': {'values': [{'caption': 'OH, MAN!',
#       'creator': 'BRIGGS',
#       'category': 'Comics/Cartoon'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e19f8c4e8c9c80001004fd6',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/wa_klickitat_ver01/data/sn87093407/00200290720/1917062901/0569.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1435.8933345485764,
#     'y': 285.83655651308493,
#     'width': 1240.8668624801078,
#     'height': 2138.729999321436,
#     'label': 'Illustration/Photo'},
#    'width': 5256,
#    'height': 6969,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn87093407/1917-06-29/ed-1/seq-3/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn87093407/1917-06-29/ed-1/seq-3/',
#     'subject_description': 'The Seattle star. June 29, 1917. Page 3',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/wa_klickitat_ver01/data/sn87093407/00200290720/1917062901/0569.xml'},
#    'data': {'values': [{'caption': 'Learn Some French Today\nTHIRD LESSON PREPARED BY MME. ARCHINARD\nMme. Archinard',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e19f496e8c9c80001004fd1',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_greenberg_ver01/data/sn85038411/00296028241/1917042801/0086.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 2270.8834026705854,
#     'y': 259.92598393234107,
#     'width': 2079.407909366775,
#     'height': 1221.652124482003,
#     'label': 'Illustration/Photo'},
#    'width': 5831,
#    'height': 7298,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85038411/1917-04-28/ed-1/seq-12/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85038411/1917-04-28/ed-1/seq-12/',
#     'subject_description': 'Harrisburg telegraph. April 28, 1917. Page 12',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_greenberg_ver01/data/sn85038411/00296028241/1917042801/0086.xml'},
#    'data': {'values': [{'caption': 'LOCAL OVERLAND DEALERS DRIVING CARS FROM FACTORY\nThe above shows one of the new sporting roadster models of the Peerless line, with Merlo Cope at the wheel. This car was delivered last week by the Keystone Moor Car Company and has attracted a great deal of attention because of its lines and attractive green coloring.',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   {'id': '5e1764ffe8c9c80001004fcb',
#    'location': {'standard': 'http://s3.amazonaws.com/ndnp-jpeg-surrogates/pst_greenberg_ver01/data/sn85038411/00296028253/1917072001/0243.jpg'},
#    'region': {'toolName': 'rectangleTool',
#     'color': '#fe0000',
#     'x': 1469.2028017430107,
#     'y': 626.5811174332181,
#     'width': 1417.3697036775225,
#     'height': 1840.8521105279374,
#     'label': 'Illustration/Photo'},
#    'width': 5825,
#    'height': 7334,
#    'meta_data': {'set_key': 'http://chroniclingamerica.loc.gov/lccn/sn85038411/1917-07-20/ed-1/seq-15/',
#     'subject_url': 'http://chroniclingamerica.loc.gov/lccn/sn85038411/1917-07-20/ed-1/seq-15/',
#     'subject_description': 'Harrisburg telegraph. July 20, 1917. Page 15',
#     'resize': '1.000000',
#     'alto': 'http://s3.amazonaws.com/ndnp-batches/pst_greenberg_ver01/data/sn85038411/00296028253/1917072001/0243.xml'},
#    'data': {'values': [{'caption': 'Three Dauphin County Aviators Now in Training\nThe three soldiers in the above picture are members of the aviation and signal corps of the United States army, two of whom are residents of this city, while the other lad hails from Lykens. These men were all prominent in athletics when they attended high school and have won the coveted school letter. They are, from left to right: John Wilier, Lykens; Arthur Winn, Harrisburg, and Paul Worcester, Harrisburg.',
#       'category': 'Photograph'}],
#     'task_prompt': "Enter picture's caption, illustrator or photographer and category."}},
#   ...]}

# %%
url_list = []
for i in range(len(metadata['data'])):
    url_list.append(metadata['data'][i]['location']['standard'])
    
url_list = list(dict.fromkeys(url_list))

# %%
# train test split
set_names = [
    " ".join(url_list[i].split('/')[-4:]).replace(' ', '_') for i in range(len(url_list))
]

# %%
def calcMD5Hash(name, split):
    return int(hashlib.md5(str(name).encode('Utf-8')).digest()[-1]) <= split * 256

# %%
train_test_hash_list = list(pd.Series(set_names).apply(lambda x: calcMD5Hash(x, 0.8)))

# %%
train_names1, test_names = [], []

for i in range(len(train_test_hash_list)):
    if train_test_hash_list[i] == True:
        train_names1.append(set_names[i])
    elif train_test_hash_list[i] == False:
        test_names.append(set_names[i])

# %%
train_val_hash_list = list(pd.Series(train_names1).apply(lambda x: calcMD5Hash(x, 0.08)))

# %%
train_names, val_names = [], []

for i in range(len(train_val_hash_list)):
    if train_val_hash_list[i] == True:
        val_names.append(train_names1[i])
    elif train_val_hash_list[i] == False:
        train_names.append(train_names1[i])

# %%
len(train_names), len(test_names), len(val_names)
# Out:
# (3666, 1032, 406)

# %%
cats, ps, x0s, y0s, x1s, y1s = [], [], [], [], [], []

for i in tqdm(range(len(metadata['data']))):
    try:
        try:
            cat = metadata['data'][i]['data']['category']
        except:
            cat = metadata['data'][i]['data']['values'][0]['category']
    except:
        print(f'Label for photo number: {i} not found, photo skipped')
        continue
    
    if cat == 'Photograph':
        cat = 0
    elif cat == 'Illustration':
        cat = 1
    elif cat == 'Map':
        cat = 2
    elif cat == 'Comics/Cartoon':
        cat = 3
    elif cat == 'Editorial Cartoon':
        cat = 4
    elif cat == 'Headline':
        cat = 5
    elif cat == 'Advertisement':
        cat = 6
        
    cats.append(cat)
    
    ps.append(" ".join(metadata['data'][i]['location']['standard'].split('/')[-4:]).replace(' ', '_'))
    
    x0s.append(int(float(metadata['data'][i]['region']['x'])))
    y0s.append(int(float(metadata['data'][i]['region']['y'])))
    x1s.append(int(float(metadata['data'][i]['region']['x']) + float(metadata['data'][i]['region']['width'])))
    y1s.append(int(float(metadata['data'][i]['region']['y']) + float(metadata['data'][i]['region']['height'])))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10245.0), HTML(value='')))
# Label for photo number: 1 not found, photo skipped
# Label for photo number: 6 not found, photo skipped
# Label for photo number: 9 not found, photo skipped
# Label for photo number: 14 not found, photo skipped
# Label for photo number: 22 not found, photo skipped
# Label for photo number: 24 not found, photo skipped
# Label for photo number: 30 not found, photo skipped
# Label for photo number: 51 not found, photo skipped
# Label for photo number: 254 not found, photo skipped
# Label for photo number: 369 not found, photo skipped
# Label for photo number: 407 not found, photo skipped
# Label for photo number: 1217 not found, photo skipped
# Label for photo number: 1576 not found, photo skipped
# Label for photo number: 2248 not found, photo skipped
# Label for photo number: 6554 not found, photo skipped
# Label for photo number: 7535 not found, photo skipped
# Label for photo number: 7904 not found, photo skipped
# Label for photo number: 8108 not found, photo skipped
# Label for photo number: 8117 not found, photo skipped
# Label for photo number: 8137 not found, photo skipped
# Label for photo number: 8449 not found, photo skipped
# Label for photo number: 9357 not found, photo skipped
# Label for photo number: 9516 not found, photo skipped
# Label for photo number: 9517 not found, photo skipped
# Label for photo number: 9528 not found, photo skipped
# Label for photo number: 9532 not found, photo skipped
# Label for photo number: 9563 not found, photo skipped
# Label for photo number: 9656 not found, photo skipped
# Label for photo number: 9680 not found, photo skipped
# Label for photo number: 9686 not found, photo skipped
# Label for photo number: 9708 not found, photo skipped
# Label for photo number: 9848 not found, photo skipped
# Label for photo number: 9870 not found, photo skipped
# Label for photo number: 10095 not found, photo skipped
# Label for photo number: 10199 not found, photo skipped

# %%
no_duplicated_names = list(dict.fromkeys(ps))

# %%
len(no_duplicated_names)
# Out:
# 5090

# %%
list_of_indexes_lists = []
for name in no_duplicated_names:
    list_of_indexes_lists.append([i for i, e in enumerate(ps) if e == name])

# %%
multi_elem_list = []
names_list = []
for j, i in enumerate(list_of_indexes_lists):
    temp_list = []
    names_list.append(no_duplicated_names[j])
    for e in range(len(i)):
        temp_list.append(f'{cats[i[e]]}/{x0s[i[e]]},{y0s[i[e]]},{x1s[i[e]]},{y1s[i[e]]}/{30}')
    
    multi_elem_list.append(temp_list)

# %%
new_train_set, new_test_set, new_val_set = [], [], []
train_name_list, test_name_list, val_name_list = [], [], []

for i, name in enumerate(names_list):
    if name in train_names:
        train_name_list.append(name)
        new_train_set.append(multi_elem_list[i])
    elif name in test_names:
        test_name_list.append(name)
        new_test_set.append(multi_elem_list[i])
    elif name in val_names:
        val_name_list.append(name)
        new_val_set.append(multi_elem_list[i])
    else:
        print(f"{name} doesn't exist in any set")

# %%
len(new_train_set), len(new_test_set), len(new_val_set)
# Out:
# (3657, 1027, 406)

# %%
len(train_name_list), len(test_name_list), len(val_name_list)
# Out:
# (3657, 1027, 406)

# %%
# check if every file is correct
scraped_photos = [
    f for f in listdir(DIR_PATH + 'scraped_photos_more_data/') if isfile(join(DIR_PATH + 'scraped_photos_more_data/', f))
]

scraped_photos.remove('.DS_Store')

# %%
check_list = train_name_list + test_name_list + val_name_list

good, bad = [], []
for i in check_list:
    if i in scraped_photos:
        good.append(1)
    else:
        bad.append(1)
        
print(f'Number of matched photos: {sum(good)}')
print(f'Number of not matched photos: {sum(bad)}')
print(f'Number of missing metadata compared to data set: {len(scraped_photos) - len(check_list)}')
# Out:
# Number of matched photos: 5090
# Number of not matched photos: 0
# Number of missing metadata compared to data set: 132

# %%
def show_random_img(names_list, coordinates_list, path_to_photos):
    random_img = random.randint(0,len(names_list))
    print(names_list[random_img])
    random_adnotation = random.randint(0,len(coordinates_list[random_img])-1)
    variables = coordinates_list[random_img][random_adnotation].split('/')
    coordinates = variables[1].split(',')
    x0, y0 = coordinates[0], coordinates[1]
    x1, y1 = coordinates[2], coordinates[3]

    box = cv2.rectangle(
        cv2.imread(
            path_to_photos + names_list[random_img]
        ),
        (int(x0), int(y0)), 
        (int(x1), int(y1)), 
        (0, 255, 0), 
        thickness=10, 
    )

    fig, ax = plt.subplots(figsize=(15, 10))
    ax.imshow(box, cmap='gray')

# %%
show_random_img(
    names_list = train_name_list + test_name_list + val_name_list,
    coordinates_list = new_train_set + new_test_set + new_val_set,
    path_to_photos = DIR_PATH + 'scraped_photos_more_data/',
)
# Out:
# sn88085187_00211108459_1917052601_0188.jpg

# %%
def final_input_transformer(input_list):
    final_list = []
    for i in range(len(input_list)):
        final_list.append(";".join(input_list[i]))
        
    return final_list

# %%
final_train_set = final_input_transformer(new_train_set)
final_test_set = final_input_transformer(new_test_set)
final_val_set = final_input_transformer(new_val_set)

# %%
# categories distribution
categories = []

for i in final_train_set:
    splitted = i.split(';')
    if len(splitted) > 1:
        for e in splitted:
            categories.append(e.split('/')[0])
    else:
        categories.append(i.split('/')[0])
    
for i in final_test_set:
    splitted = i.split(';')
    if len(splitted) > 1:
        for e in splitted:
            categories.append(e.split('/')[0])
    else:
        categories.append(i.split('/')[0])
    
for i in final_val_set:
    splitted = i.split(';')
    if len(splitted) > 1:
        for e in splitted:
            categories.append(e.split('/')[0])
    else:
        categories.append(i.split('/')[0])
    
cat_series = pd.Series(categories)

cat_series = cat_series.map({
    '0': 'fotografia', 
    '1': 'ilustracja',
    '2': 'mapa', 
    '3': 'komiks/karykatura',
    '4': 'karykatura polityczna', 
    '5': 'nagłówek',
    '6': 'reklama',
})

cat_series.value_counts()
# Out:
# fotografia               6130
# komiks/karykatura        1849
# ilustracja               1665
# karykatura polityczna     448
# mapa                      118
# dtype: int64

# %%
# save files in final shape
def save_list_to_tsv_file(path, output_list):
    with open(path, 'w', newline='') as f_output:
        tsv_output = csv.writer(f_output, delimiter='\t')
        tsv_output.writerow(output_list)

# %%
# train:
save_list_to_tsv_file(DIR_PATH + 'Master_gonito/train/expected.tsv', final_train_set)
save_list_to_tsv_file(DIR_PATH + 'Master_gonito/train/in.tsv', train_name_list)

# test:
save_list_to_tsv_file(DIR_PATH + 'Master_gonito/test-A/expected.tsv', final_test_set)
save_list_to_tsv_file(DIR_PATH + 'Master_gonito/test-A/in.tsv', test_name_list)

# val:
save_list_to_tsv_file(DIR_PATH + 'Master_gonito/dev-0/expected.tsv', final_val_set)
save_list_to_tsv_file(DIR_PATH + 'Master_gonito/dev-0/in.tsv', val_name_list)
